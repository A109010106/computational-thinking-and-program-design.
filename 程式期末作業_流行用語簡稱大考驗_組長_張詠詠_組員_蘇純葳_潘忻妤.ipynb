# %% [markdown]
# <a href="https://colab.research.google.com/github/A109010106/computational-thinking-and-program-design./blob/main/%E7%A8%8B%E5%BC%8F%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%AD_%E6%B5%81%E8%A1%8C%E7%94%A8%E8%AA%9E%E7%B0%A1%E7%A8%B1%E5%A4%A7%E8%80%83%E9%A9%97_%E7%B5%84%E9%95%B7_%E5%BC%B5%E8%A9%A0%E8%A9%A0_%E7%B5%84%E5%93%A1_%E8%98%87%E7%B4%94%E8%91%B3_%E6%BD%98%E5%BF%BB%E5%A6%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("請輸入你的名字:")
print("哈囉", name, "!我是現代年輕人簡寫高手呢")
print("你是不是有很多網路流行簡寫看不懂呢?")
print("試著輸入一些簡寫用語來讓我為你解答吧")
print("如果要輸入英文有關的簡寫用語記得要大寫喔")
print("這是底下文章會使用到的用語:\n1.情勒\n2.景夜\n3.生快\n4.北車\n5.隱眼\n6.永豆\n7.UQ\n8.郭\n9.中客\n10.北捷\n11.累點\n12.穩單\n13.高玩\n14.平美\n15.水逆\n16.穩交\n17.大奶微微\n18.服學\n19.限動\n")
lxy = input("請輸入簡寫用語:")
if lxy=="情勒":
    print(lxy,"意思是情緒勒索")
    print("例句: A:你如果不愛我我就要去死 B:不要在對我情勒了!")
    print("高手:這種問題好簡單!!!")
elif lxy=="景夜":
    print(lxy,"意思是景美夜市")
    print("例句:下課一起去景夜吧!")
    print("高手:下次可以這樣約同學們了!")
elif lxy=="生快":
    print(lxy,"意思是生日快樂")
    print("例句:祝我朋友生快")
    print("高手:少打兩個字是不是很輕鬆")
elif lxy=="北車":
    print(lxy,"意思台北車站")
    print("例句: A:欸我今天會到台北喔!  B: 那北車見啊!")
    print("高手:這樣你學會了嗎?")
elif lxy=="隱眼":
    print(lxy,"意思是隱形眼鏡")
    print("例句:這次出遊我戴新的隱眼ㄟ!")
    print("高手:好方便!你學會了嗎???")
elif lxy=="永豆":
    print(lxy,"意思是永和豆漿")
    print("例句: 今天宵夜一起去吃永豆吧!!!")
    print("高手:唉呦~到底要多簡寫呢!")
elif lxy=="UQ":
    print(lxy,"意思是UNIQLO")
    print("例句: A:欸我想要挑面試的衣服 B:那下班一起逛UQ阿!")
    print("高手:連這個都不懂...是在哈囉喔~")
elif lxy=="郭":
    print(lxy,"意思是關我屁事")
    print("例句: A:我交女朋友了ㄟ! B:郭喔!")
    print("高手:這個你也不懂..要加把勁喔!")
elif lxy=="中客":
    print(lxy,"意思是台中客運")
    print("例句: 這次返鄉要一起坐中客嗎?")
    print("高手:這樣你學會了嗎?")
elif lxy=="北捷":
    print(lxy,"意思是台北捷運")
    print("例句: 北捷的圖標換新得你不知道嗎?")
    print("高手:這個也不懂?")
elif lxy=="累點":
    print(lxy,"形容累積點數")
    print("例如：最近7-11的活動你有在累點嗎?")
    print("高手:這樣你學會了嗎?")
elif lxy=="穩單":
    print(lxy,"意思是穩定單身")
    print("例句：A: 她的facebook感情狀態顯示穩單！yessss我有機會追到他了！")
    print("高手:這樣你學會了嗎?")
elif lxy=="高玩":
    print(lxy,"意思是高級玩家形容很會玩遊戲的人")
    print("例句：A: 我傳說已經爬到星耀了!B:那妳真是傳說高玩...")
    print("高手:這樣你懂了嗎?")
elif lxy=="平美":
    print(lxy,"是平民美食的意思")
    print("例句：下課一起去景夜吃平美吧！")
    print("高手:這個你也不懂..要加把勁喔!")
elif lxy=="水逆":
    print(lxy,"意思是水星逆轉運氣差")
    print("例句：最近諸事不順一定是水逆的關係！")
    print("高手:這樣學會了嗎?")
elif lxy=="穩交":
    print(lxy,"意思是穩定交往中喔")
    print("例句：A:你和小美最近還好嗎? B:正在穩交阿!")
    print("高手:這樣搞懂了嗎?")
elif lxy=="大奶微微":
    print(lxy,"意思是大杯奶茶微糖微冰")
    print("例句：我最喜歡去清心點大奶微微了。")
    print("高手:這樣你學會了嗎?")
elif lxy=="服學":
    print(lxy,"意思是服務學習")
    print("例句：A:老師說這次服學沒有人及格 B:蛤傻眼ㄟ那我們不都完蛋")
    print("高手:這個你也不懂..要加把勁喔!")
elif lxy=="限動":
    print(lxy,"表示IG上的限時動態")
    print("例句：A:這間餐廳很好吃ㄟ你在哪找的?B:老吳的限動阿!")
    print("高手:這樣你學會了嗎?")
else:
    print("哇哇哇哇...高手被考倒了!!變成低能兒了嗚嗚嗚嗚\n")



print("經過上面的惡補與學習")
print("相信你也成為一位網路流行簡寫喽~")
print("既然你哪麼厲害就一定要參加網路流行簡寫大賽呀!")
print("本比賽是要考核你是否學會了上面所教的網路流行簡寫")
print("我們運用情境式的題目進行考核")
print("本比賽共有11題")
print("答錯一題視同挑戰失敗")
print("所以各位要謹慎作答喔!")
name=input("請輸入你的名字:")
print(name , "你準備好了嗎?")
choose=input("輸入YES或NO:")
while choose == "YES":
    print("比賽開始!!!!")
    print("你今天和男朋友吵架")
    print("不管你怎麼道歉他都不原諒你")
    print("還威脅你說要分手")
    print("問你是不是不愛他了才讓他傷心")
    print("你覺得他真的在胡鬧")
    print("請問他是 情勒 OR 高玩? ")
    q1=input("請輸入請輸入情勒 OR 高玩:")
    if q1 == "情勒":
        print("Bingo!離成功的路還有一段距離加油!!!")
        print("男朋友一直威脅你他要跳樓")
        print("男朋友:你會陪我跳嗎?")
        a1=input("請輸入YES或NO: ")
        if a1 == "YES":
            print("男朋友:那我們可以回到從前嗎?")
            print("請問你要回答 好啊~一起穩交 OR 好啊~生快!")
            q2=input("請輸入穩交或生快: ")
            print("男朋友沒有要鬆手的意思")
            if q2 == "穩交":
                print("男朋友:那真是太好了")
                print("一起吃飯的時候")
                print("你發現男朋友一直揉眼睛")
                print("他叫你去幫他買 隱眼 OR UQ!!")
                q3=input("請輸入隱眼 OR UQ:")
                if q3 == "隱眼":
                    print("答對了!離成功的路還有一段距離加油!!!")
                    print("你覺得自己真貼心")
                    print("心裡想著如果沒有你會怎樣?")
                    print("這時候男朋友 突然說...")
                    print("男朋友:我不喜歡吃太貴的餐廳")
                    print("男朋友:而且覺得跟你在一起哪裡都好")
                    print("你覺得非常驚訝")
                    print("這時候你要回答他下次一起去吃 平美 OR 服學")
                    q4=input("請輸入 平美 OR 服學:")
                    if q4 == "平美":
                        print("Bingo!離成功的路不遠加油!!!")
                        print("男朋友覺得你很懂他 開心的笑了")
                        print("你想既然他不吃餐廳的話 那夜市總吃吧!?")
                        print("他開心地說這裡是哪裡")
                        print("你跟他解釋這是夜市")
                        print("他告訴你他從來沒來過這裡")
                        print("你覺得不可思議")
                        print("所以你告訴他這裡是 景夜 OR 北車")
                        q5=input("請輸入 景夜 OR 北車: ")
                        if q5 == "景夜":
                            print("恭喜答對!離成功的路不遠喽~加油!!!")
                            print("在你的說服之下他吃了許多平美")
                            print("但他咬了幾口吐了出來")
                            print("你覺得他覺得這食物太乾了")
                            print("你會說 還是你要喝大奶微微 0R 水逆 OR 北捷")
                            q6=input("請輸入 大奶微微 0R 水逆 OR 生快: ")
                            if q6 == "大奶微微":
                                print("Bingo!離成功的路不遠加油!!!")
                                print("男朋友發現大奶微微很好喝")
                                print("他決定繼續把大奶微微喝完")
                                print("並且把好吃的全部都給你")
                                print("這時你們已經和好了")
                                print("但是有點累了")
                                print("所以你問他要怎麼回板橋")
                                print("你要問他要坐 北捷嗎? OR 要坐中客嗎? OR 郭嗎?")
                                q7=input("請輸入坐 北捷 OR 中客 OR 郭: ")
                                if q7 == "郭":
                                    print("男朋友:喔...好吧;(")
                                    print("你不跟男朋友回家 故事無法繼續 挑戰失敗")
                        else:
                            print("答錯了!挑戰失敗真的只差一點點耶...")
                    else:
                            print("答錯了!挑戰失敗真的只差一點點耶...")
                else:
                            print("答錯了!挑戰失敗真的只差一點點耶...")
            else:
                            print("答錯了!挑戰失敗真的只差一點點耶...")
        else:
                            print("答錯了!挑戰失敗真的只差一點點耶...")
    else:
                            print("答錯了!挑戰失敗真的只差一點點耶...")
else:
    print("再讓你準備一下喔!!!")
# Out:
# 請輸入你的名字:annie
# 哈囉 annie !我是現代年輕人簡寫高手呢
# 你是不是有很多網路流行簡寫看不懂呢?
# 試著輸入一些簡寫用語來讓我為你解答吧
# 如果要輸入英文有關的簡寫用語記得要大寫喔
# 這是底下文章會使用到的用語:
# 1.情勒
# 2.景夜
# 3.生快
# 4.北車
# 5.隱眼
# 6.永豆
# 7.UQ
# 8.郭
# 9.中客
# 10.北捷
# 11.累點
# 12.穩單
# 13.高玩
# 14.平美
# 15.水逆
# 16.穩交
# 17.大奶微微
# 18.服學
# 19.限動
#
# 請輸入簡寫用語:15
# 哇哇哇哇...高手被考倒了!!變成低能兒了嗚嗚嗚嗚
#
# 經過上面的惡補與學習
# 相信你也成為一位網路流行簡寫喽~
# 既然你哪麼厲害就一定要參加網路流行簡寫大賽呀!
# 本比賽是要考核你是否學會了上面所教的網路流行簡寫
# 我們運用情境式的題目進行考核
# 本比賽共有11題
# 答錯一題視同挑戰失敗
# 所以各位要謹慎作答喔!
